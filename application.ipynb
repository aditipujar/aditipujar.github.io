# %% [markdown]
# # Yup this entire thing is in Markdown.
#
# https://dl4sci-school.lbl.gov/dates

# %% [markdown]
# - [ ] List any deep learning projects you have worked on. Provide brief details about one project.
#
# I have worked on two projects that used deep learning methods. The first was in chaos, to develop a meaningful low dimensional embedding in order to find the "manifold of unstable periodic orbits" (can be colloquially understood as the )
#
# More recently I have worked on training normalising flows to model the black hole recoil velocity. We found that the kick differences were nearly gaussian so I trained a conditional Gaussian Neural network to get the mu and sigma as a function of the black hole parameters. But as that was not general enough, added skew which took me to interesting ways of defining the negative log likelihood for a skewed Normal distribution.
#
# - [ ] Why do you want to attend this summer school on deep learning.
#
# - [ ] Webpage. LEUP publication. Then under coming soon - chaos animations AND binary black hole animations.
